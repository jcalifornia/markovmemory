# %%
# %pylab inline
from simulation import *
from scipy.stats import gamma
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.offsetbox import AnchoredText
import sys
import matplotlib
matplotlib.rcParams['text.usetex'] = True
matplotlib.rcParams['text.latex.unicode'] = True
matplotlib.rcParams['text.latex.preamble']=[r"\usepackage{amsmath}"]
import re
import matplotlib.gridspec as gridspec
import os
from palettable.colorbrewer.qualitative import Set1_5
from scipy.special import gammaln, polygamma
import pandas as pd
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
dataset = pd.read_csv("free_throws.csv")

# %%
dataset['outcome'] = dataset['shot_made'].astype(str)

# %%
dataset['outcome'] = dataset['outcome'].replace("1","+").replace("0","-")

# %%
grouped = dataset.groupby(['player','game_id','season'])

# %%
temp = grouped['outcome'].apply(lambda x: sum(x))

# %%
freethrows = temp.reset_index()
freethrows.head()
# Out:
#        player      game_id       season outcome
# 0  A.J. Price  291111011.0  2009 - 2010      +-
# 1  A.J. Price  291122030.0  2009 - 2010       +
# 2  A.J. Price  291216011.0  2009 - 2010       +
# 3  A.J. Price  291226011.0  2009 - 2010      ++
# 4  A.J. Price  291227014.0  2009 - 2010     ++-

# %%
freethrows.loc[freethrows['player'] == 'LeBron James']
# Out:
# ['---+-+',
#  '-+++---++-+',
#  '++++++++-+',
#  '+-+---++--+',
#  '+++-++++',
#  '+++++++-++-++++++++++--',
#  '-++-+++-+',
#  '++++--+++++',
#  '++++++-++-+++-',
#  '++++-',
#  '-',
#  '++-+++--+',
#  '-+-+++++++-+++++-+++',
#  '+--++-+',
#  '+-++-++-++-',
#  '--++--++++',
#  '++-++-+',
#  '-+++-',
#  '+++-+-',
#  '+',
#  '++-++++++++',
#  '-++',
#  '+++-+-+++',
#  '+++++-+++++-++-+--+++',
#  '++++++++',
#  '---+++-+--',
#  '-+++-+++',
#  '+-++-++-+-+-+',
#  '---',
#  '+-+-+--+--+',
#  '+-+-++++++',
#  '++',
#  '+++',
#  '-+',
#  '++++++++',
#  '+++++++-+++-+++',
#  '--+--+--+++-+',
#  '+++++++++++--+',
#  '+-+--',
#  '+--+++++-----',
#  '-+++-++++-+--',
#  '--+-++',
#  '-+-+---+',
#  '+++----+',
#  '-++',
#  '++',
#  '--+-++-+',
#  '+++---++-+++',
#  '-+-+-+-++',
#  '++++-++++++-+++-+++-++',
#  '++',
#  '+++++',
#  '-+--+---',
#  '++-++-+-+--+',
#  '+++---+',
#  '++--++--',
#  '+++-++++++++++-++',
#  '++-+--++-',
#  '++-+++-+',
#  '++++',
#  '++++-',
#  '-+--++',
# ...

# %%
freethrows.to_csv("game_freethrows.csv",index=False)
