# %%
# %pylab inline
from simulation import *
num_cores = multiprocessing.cpu_count() - 1
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid.anchored_artists import AnchoredText
import sys
import matplotlib
matplotlib.rcParams['text.usetex'] = True
matplotlib.rcParams['text.latex.unicode'] = True
import matplotlib.gridspec as gridspec
import pickle, gzip
matplotlib.rcParams['text.latex.preamble']=[r"\usepackage{amsmath}"]
from palettable.colorbrewer.qualitative import Set1_5


with gzip.open('simulation_results.gz','rb') as f:
    results = pickle.load(f)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
histograms = defaultdict(partial(np.zeros,5,dtype=int))

for h,h_result in enumerate(results):
    # these results have a single true q
    for j,result_set in enumerate(h_result):
        # each set is a single replication (should be J of these)
        for info in result_set:
            for key, val in info.items():
                best = np.argmin([v for v in val.values()])
                hvals = [v for v in val.keys()]
                histograms[(key,h+1,j)][best] += 1

# %%
criteria = ['WAIC1','WAIC2','LOO','LPPDCV2','DIC1','DIC2','AIC',  'LPD']
criteria.reverse()

pretty_labels = ['WAIC$_1$','WAIC$_2$','LOO','LPPDCV$_2$','DIC$_1$','DIC$_2$','AIC',  'LPD']
pretty_labels.reverse()
colors = Set1_5.hex_colors

# %% [raw]
# # histograms here
# # rows: information
# # columns: 2^J samples
# fig = plt.figure(figsize=(24,20))
# gs0 = gridspec.GridSpec(5,5, hspace = 0.05,wspace=0.05)
# ax = []
#
#
#
# for J in range(5): # enumerate row-wise
#     for Q in range(5):
#         ax+= [plt.Subplot(fig,gs0[J,Q])]
#         fig.add_subplot(ax[-1])
#         cumulative = np.zeros(len(criteria))
#         for q in range(5):
#             widths = np.array([np.sum(histograms[(quantity, J+1,Q)][q]) for quantity in criteria])
#             ax[-1].barh(range(len(criteria)), widths,
#                 color=colors[q],align='center',alpha=0.9,left = cumulative )
#             cumulative += widths
#
#         ax[-1].set_xlim((0,10000))
#         ax[-1].set_xticks([])
#         ax[-1].set_yticks([])
#         ax[-1].spines["top"].set_visible(False)
#         ax[-1].spines["right"].set_visible(False)
#         ax[-1].spines["bottom"].set_visible(False)
#         ax[-1].spines["left"].set_visible(False)
#         ax[-1].set_ylim((-0.5,8.5))
#
#
# for p in range(5):
#     ax[5*p].set_yticks(range(len(criteria)))
#     ax[5*p].set_yticklabels(pretty_labels,fontsize=16)
#     ax[5*p].set_ylabel("q="+str(p+1),fontsize=24,color=colors[p])
#     ax[p].set_title(str(4**(p+1)) + " trajectories",fontsize=24)
#     ax[5*p+4].set_yticks(range(len(criteria)))
#     ax[5*p+4].yaxis.tick_right()
#     ax[5*p+4].set_yticklabels(pretty_labels,fontsize=16)
#
# #plt.savefig('../figures/fig2.png',bbox_inches='tight',
# #               transparent=True,
# #               pad_inches=0.15, dpi=400)
# #plt.savefig('../figures/fig2.pdf',bbox_inches='tight',
# #               transparent=True,
# #               pad_inches=0.15, dpi=400)

# %%
# histograms here
# rows: information
# columns: 2^J samples
fig = plt.figure(figsize=(18,19))
gs0 = gridspec.GridSpec(5,5, hspace = 0.05,wspace=0.05)
ax = []

for J in range(5): # enumerate row-wise
    for Q in range(5):
        ax+= [plt.Subplot(fig,gs0[J,Q])]
        fig.add_subplot(ax[-1])
        cumulative = np.zeros(len(criteria))
        for q in range(5):
            widths = np.array([np.sum(histograms[(quantity, J+1,Q)][q]) for quantity in criteria])
            ax[-1].barh(range(len(criteria)), widths,
                color=colors[q],align='center',alpha=0.9,left = cumulative )
            for l,w in enumerate(widths):
                # decide if we want to label some information
                if w>2000:
                    ax[-1].text(cumulative[l]+w/2,l,"{0:.0f}\%".format(w/100),
                                ha="center",va="center",color='w',fontweight='black',fontsize=18)
            cumulative += widths

        ax[-1].set_xlim((0,10000))
        ax[-1].set_xticks([])
        ax[-1].set_yticks([])
        ax[-1].spines["top"].set_visible(False)
        ax[-1].spines["right"].set_visible(False)
        ax[-1].spines["bottom"].set_visible(False)
        ax[-1].spines["left"].set_visible(False)
        ax[-1].set_ylim((-0.5,len(criteria)-.5))

        
for p in range(5):
    ax[5*p].set_yticks(range(len(criteria)))
    ax[5*p].set_yticklabels(pretty_labels,fontsize=16)
    ax[5*p].set_ylabel(r"$\boldsymbol{h_{\textrm{true}}="+str(p+1)+"}$",fontsize=24,color=colors[p])
    ax[p].set_title("$J=" + str(4**(p+1)) + "$",fontsize=24)
    ax[5*p+4].set_yticks(range(len(criteria)))
    ax[5*p+4].yaxis.tick_right()
    ax[5*p+4].set_yticklabels(pretty_labels,fontsize=16)
    
plt.savefig('../figures/fig2.png',bbox_inches='tight', 
               transparent=True,
               pad_inches=0.15, dpi=400)
plt.savefig('../figures/fig2.pdf',bbox_inches='tight', 
               transparent=True,
               pad_inches=0.15, dpi=400)
